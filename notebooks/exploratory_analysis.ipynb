# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src.analytics.funnel_metrics import calculate_funnel
from src.analytics.traffic_analysis import traffic_performance
from src.analytics.cohort import cohort_analysis
from src.analytics.kpi_monitor import monitor_kpis
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 5 from src.analytics.funnel_metrics import calculate_funnel
#       6 from src.analytics.traffic_analysis import traffic_performance
#       7 from src.analytics.cohort import cohort_analysis
#
# ModuleNotFoundError: No module named 'src'

# %%
df = pd.read_csv('../data/processed/clean_events.csv')

print(df.head())

# %%
print(df.info())
print(df.describe())

# %%
funnel = calculate_funnel(df)
print(funnel)

# %%
traffic = traffic_performance(df)
print(traffic)

# %%
kpis = monitor_kpis(df)
print(kpis)

# %%
cohort = cohort_analysis(df)

plt.figure(figsize=(12,6))
sns.heatmap(cohort, annot=True, cmap='Blues')
plt.title('Cohort Retention Matrix')
plt.show()

# %%
revenue = df.groupby('traffic_source')['revenue'].sum()

revenue.plot(kind='bar')
plt.title('Revenue by Traffic Source')
plt.show()
